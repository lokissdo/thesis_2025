# %%
rm -rf /kaggle/working/thesis_2025

# %%
# %cd /kaggle/working

# %%
# !git clone https://github.com/lokissdo/thesis_2025.git

# %%
# %cd /kaggle/working/thesis_2025/evaluate/ACE

# %%
# %%writefile /kaggle/working/thesis_2025/evaluate/ACE/data_transfer_eval.sh
# #!/bin/bash
# ROOT_DIR="/kaggle/input/pgd-attack-multiple-masks/pgd_attack_multiple_masks/bld_multiple_masks_threshold04"
# OUT_DIR="/kaggle/working"
# EVAL_MODEL_DIR="/kaggle/working/thesis_2025/evaluate"
#
# python3 data_transfer_eval.py --root_dir "$ROOT_DIR" --out_dir "$OUT_DIR" --eval_model_dir "$EVAL_MODEL_DIR"

# %%
# !bash /kaggle/working/thesis_2025/evaluate/ACE/evaluate_combined.sh > /kaggle/working/bld_multiple_masks_threshold04.txt 2>&1
