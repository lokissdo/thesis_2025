# %%
rm -rf /kaggle/working/thesis_2025

# %%
# %cd /kaggle/working

# !git clone --branch hv-adversarial-attack --single-branch https://github.com/lokissdo/thesis_2025.git

# %%
# %cd /kaggle/working/thesis_2025/adversarial_attack

# %%
# !bash /kaggle/working/thesis_2025/adversarial_attack/run_attack_cli.sh
