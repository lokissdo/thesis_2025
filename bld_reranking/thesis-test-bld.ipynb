# %%
rm -rf /kaggle/working/thesis_2025

# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
# !git clone --branch hv-bld-reranking --single-branch https://github.com/lokissdo/thesis_2025.git

# %%
# !pip install open-clip-torch

# %%
# !pip install -r /kaggle/working/thesis_2025/requirements.txt

# %%
# %cd /kaggle/working/thesis_2025/bld_reranking

# %%
# !bash /kaggle/working/thesis_2025/bld_reranking/generate_bld_img.sh

# %% [markdown]
# ####
